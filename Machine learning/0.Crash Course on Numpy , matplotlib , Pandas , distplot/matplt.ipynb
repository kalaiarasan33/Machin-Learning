# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plot

# %%
i=pd.read_csv("iris.csv")
sl=i["sepal_length"]
sw=i["sepal_width"]
pl=i["petal_length"]
pw=i["petal_width"]
val=pd.DataFrame({"x":[1,2,3,4],"y":[2,4,5,6],"z":[1,3,4,5]})
x=val["x"]
y=val["y"]
z=val["z"]

# %%
plot.plot(sl)
plot.xlabel("x values")
plot.ylabel("y values")
plot.legend()
plot.title("line plot")
# Out:
# Text(0.5, 1.0, 'line plot')

# %%
s1=sl.head(10)
s2=sw.head(10)
l=np.arange(len(s1))
plot.bar(l+0.2,s1,width=0.2,label="sepal lengt")
plot.bar(l,s2,width=0.2,label="sepal width")
#plot.yticks(np.arange(7),("1st","2nd","3rd","4th","5th","6th"))
plot.legend()

# %%
popu=[np.random.randint(1,100,30)]
plot.hist(popu,histtype="bar",rwidth=0.5)
plot.yticks(np.arange(6),(0,2001,2002,2003,2004,2005,2006))
# Out:
# ([<matplotlib.axis.YTick at 0x7ff603c89860>,
# ...
#  <a list of 6 Text yticklabel objects>)

# %%
h=np.random.randint(1,100,50)
k=np.random.randint(1,100,50)

plot.hist(h,histtype="bar",rwidth=0.5)
plot.hist(k,histtype="bar",rwidth=0.5)
# Out:
# (array([6., 4., 6., 7., 5., 8., 1., 3., 5., 5.]),
#  array([ 1. , 10.8, 20.6, 30.4, 40.2, 50. , 59.8, 69.6, 79.4, 89.2, 99. ]),
#  <a list of 10 Patch objects>)

# %%
x=np.random.randint(1,20,10)
y=np.random.randint(1,20,10)
x1=np.random.randint(1,20,10)
y1=np.random.randint(1,20,10)

# %%
plot.scatter(x,y,label="x",s=80,marker="<")
plot.scatter(x1,y1,label="y",s=40,marker=">",color="g")
plot.legend()

# %%
plot.scatter(sl,sw)
plot.scatter(pl,pw)
plot.legend()

# %%
plot.subplot(311)
plot.scatter(sl,sw)
plot.legend()
plot.subplot(312)
plot.scatter(pl,pw)
plot.legend()
plot.subplot(313)
plot.scatter(pl,pw)
plot.legend()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(sl,sw,pl,l)
ax.legend()
# Out:
# No handles with labels found to put in legend.

# %%
slices=[25,25,25,25]
act=["sleep","eating","walking","programming"]
clr=["g","r","y","b"]
plot.pie(slices,labels=act,colors=clr,startangle=50,shadow=True,explode=(0.01,0.01,0.01,0.01),autopct="%1.0f%%")
plot.title("Pie plot")
plot.legend()
